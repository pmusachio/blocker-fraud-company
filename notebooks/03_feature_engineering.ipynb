# %% [markdown]
# # Blocker Fraud Company - Feature Engineering
#
# Comparison between raw data and features prepared for modeling.

# %%
from pathlib import Path
import sys
import json

PROJECT_ROOT = Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from blocker_fraud_company.config import load_config
from blocker_fraud_company.data import load_training_frame, profile_dataframe
from blocker_fraud_company.features import prepare_features

config = load_config()
config["project"]

# %%
df = load_training_frame(config)
features = prepare_features(df.copy(), config)
print('raw shape:', df.shape)
print('feature shape:', features.shape)
features.head()

# %%
new_columns = sorted(set(features.columns) - set(df.columns))
new_columns[:50], len(new_columns)

# %% [markdown]
# ## Feature rationale
#
# - Balance-delta features and the ratio between amount and origin balance.
# - Supervised model with class weighting for fraud.
# - Score-based ranking to prioritize operational investigation.
