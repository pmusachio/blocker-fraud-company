# %% [markdown]
# # Blocker Fraud Company - Modeling and Business Results
#
# Pipeline execution, metrics review and business translation.

# %%
from pathlib import Path
import sys
import json

PROJECT_ROOT = Path.cwd().resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

from blocker_fraud_company.config import load_config
from blocker_fraud_company.data import load_training_frame, profile_dataframe
from blocker_fraud_company.features import prepare_features

config = load_config()
config["project"]

# %%
RUN_PIPELINE = False

if RUN_PIPELINE:
    from blocker_fraud_company.cli import main
    main(['train'])
else:
    print('Defina RUN_PIPELINE = True para executar o fluxo neste notebook.')

# %%
from pathlib import Path
import json

for path in [Path('reports/metrics.json'), Path('reports/ab_test_results.json')]:
    if path.exists():
        display(json.loads(path.read_text()))

if Path('reports/price_elasticity.csv').exists():
    import pandas as pd
    display(pd.read_csv('reports/price_elasticity.csv').head(20))

# %% [markdown]
# ## Business Translation
#
# The result lets us estimate how much financial value stays protected by reviewing the highest-scored transactions first.

# %% [markdown]
# ## Next Steps
#
# - Calibrate the threshold using the cost of false positives vs. false negatives.
# - Add per-feature explainability to support fraud analysts.
# - Monitor drift in transaction types and amount distributions.
